# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm

# %%
df=pd.read_excel('netflix_database.xlsx')
df.head()
# Out:
#          week      category                    show_title  \
# 0  2023-11-19  TV (English)                     The Crown
# 1  2023-11-19  TV (English)  Matt Rife: Natural Selection
# 2  2023-11-19  TV (English)   All the Light We Cannot See
# 3  2023-11-19  TV (English)      How to Become a Mob Boss
# 4  2023-11-19  TV (English)          Escaping Twin Flames
#
#    weekly_hours_viewed     cast_member_1   cast_member_2    cast_member_3  \
# 0             36900000   Imelda Staunton  Jonathan Pryce  Lesley Manville
# 1              7900000         Matt Rife             NaN              NaN
# 2             21700000  Aria Mia Loberti   Louis Hofmann     Mark Ruffalo
# 3             11900000    Peter Dinklage             NaN              NaN
# 4              9400000               NaN             NaN              NaN
#
#               genre_1                  genre_2  genre_3         mood_1  \
# 0  Political TV Shows                TV Dramas  British       Intimate
# ...
